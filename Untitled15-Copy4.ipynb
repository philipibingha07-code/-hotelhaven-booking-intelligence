# %%
# Import libraries

import  pandas as pd   #dataframes for working with tabular data
import numpy  as np  # numerical operations

#visulization
import matplotlib.pyplot as plt 
import seaborn as sns

#scikit learn  machine learning 
# Machine preprocessing 
from sklearn.model_selection import train_test_split   # split data into train/test sets
from sklearn.preprocessing import StandardScaler  # standardize numerical features / columns
from sklearn.preprocessing import LabelEncoder  # Encode categorical columns


#machine learning Model 
from sklearn.linear_model import LogisticRegression 
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier 


# Machine Learning Evaluation

from sklearn.metrics import (accuracy_score, 
                               precision_score, 
                               recall_score, 
                               f1_score, 
                               confusion_matrix,
                               classification_report, 
                               roc_auc_score,
                               roc_curve)

#Setting
import warnings
warnings.filterwarnings('ignore')

sns.set_style ('whitegrid')
plt.rcParams['figure.figsize'] = (10,6)

#Set random seed for reproducility

RANDOM_STATE = 42

print("All libraries imported successfully!")
# Out:
# All libraries imported successfully!

# %%
import pandas as pd

Data_booking = "booking - booking (1).xlsx_csv.xlsx"

df = pd.read_excel(Data_booking)

print("Data loaded successfully!")
print(f"shape: {df.shape[0]} rows x {df.shape[1]} columns")
print("data loaded successfully")
# Out:
# Data loaded successfully!
# shape: 36285 rows x 17 columns
# data loaded successfully

# %%
df.head(10)
# Out:
#   Booking_ID  number of adults  number of children  number of weekend nights  \
# 0   INN00001                 1                   1                         2
# 1   INN00002                 1                   0                         1
# 2   INN00003                 2                   1                         1
# 3   INN00004                 1                   0                         0
# 4   INN00005                 1                   0                         1
# 5   INN00006                 1                   0                         0
# 6   INN00007                 1                   1                         1
# 7   INN00008                 3                   0                         1
# 8   INN00009                 1                   1                         0
# 9   INN00010                 2                   0                         0
#
#    number of week nights  type of meal  car parking space    room type  \
# ...

# %%
## remaning my columns

# %%
df["Lead_time"]
# Out:
# 0        224
# 1          5
# 2          1
# 3        211
# 4         48
#         ...
# 36280    346
# 36281     34
# 36282     83
# 36283    121
# 36284     44
# Name: Lead_time, Length: 36248, dtype: int64

# %%
df = df.rename(columns={"number of adults": "No_of_adult",
                        "number of children": "No_of_children",
                        "number of weekend nights": "No_of_weekendnights",
                        "number of week nights": "No_of weeknights",
                        "number of week nights": "No_of weeknights",
                        "type of meal": "Meal_type",
                        "car parking space": "Car_parking",
                        "room type": "Room_type",
                        "lead time": "Lead_time",
                       "market segment type": "Market_seg_type",
                        "average price": "Average_price",
                        "special requests": "Special_request",
                        "date of reservation": "Date_of_reservation"})

# %%
# Convert to datetime safely
df["Date_of_reservation"] = pd.to_datetime(
    df["Date_of_reservation"],
    errors="coerce")

# Check invalid dates
print(df["Date_of_reservation"].isnull().sum())
# Out:
# 37

# %%
# Extract year
df["Year"] = df["Date_of_reservation"].dt.year

# Extract month
df["Month"] = df["Date_of_reservation"].dt.month

# %%
df.head()
# Out:
#   Booking_ID  No_of_adult  No_of_children  No_of_weekendnights  \
# 0   INN00001            1               1                    2
# 1   INN00002            1               0                    1
# 2   INN00003            2               1                    1
# 3   INN00004            1               0                    0
# 4   INN00005            1               0                    1
#
#    No_of weeknights     Meal_type  Car_parking    Room_type  Lead_time  \
# 0                 5   Meal Plan 1            0  Room_Type 1        224
# 1                 3  Not Selected            0  Room_Type 1          5
# 2                 3   Meal Plan 1            0  Room_Type 1          1
# 3                 2   Meal Plan 1            0  Room_Type 1        211
# 4                 2  Not Selected            0  Room_Type 1         48
#
#   Market_seg_type  repeated  P-C  P-not-C  Average_price  Special_request  \
# 0         Offline         0    0        0          88.00                0
# ...

# %%
df.describe()
# Out:
#         No_of_adult  No_of_children  No_of_weekendnights  No_of weeknights  \
# count  36248.000000    36248.000000         36248.000000      36248.000000
# mean       1.845178        0.105302             0.810445          2.204508
# min        0.000000        0.000000             0.000000          0.000000
# 25%        2.000000        0.000000             0.000000          1.000000
# 50%        2.000000        0.000000             1.000000          2.000000
# 75%        2.000000        0.000000             2.000000          3.000000
# max        4.000000       10.000000             7.000000         17.000000
# std        0.518671        0.402597             0.870938          1.410825
#
#           Meal_type   Car_parking     Room_type     Lead_time  \
# count  36248.000000  36248.000000  36248.000000  36248.000000
# mean       0.516056      0.030926      0.708425     85.282360
# min        0.000000      0.000000      0.000000      0.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36285 entries, 0 to 36284
# Data columns (total 19 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Booking_ID           36285 non-null  object
#  1   No_of_adult          36285 non-null  int64
#  2   No_of_children       36285 non-null  int64
#  3   No_of_weekendnights  36285 non-null  int64
#  4   No_of weeknights     36285 non-null  int64
#  5   Meal_type            36285 non-null  object
#  6   Car_parking          36285 non-null  int64
#  7   Room_type            36285 non-null  object
#  8   Lead_time            36285 non-null  int64
#  9   Market_seg_type      36285 non-null  object
#  10  repeated             36285 non-null  int64
#  11  P-C                  36285 non-null  int64
#  12  P-not-C              36285 non-null  int64
#  13  Average_price        36285 non-null  float64
#  14  Special_request      36285 non-null  int64
# ...

# %%
df.isnull().sum()
# Out:
# Booking_ID              0
# No_of_adult             0
# No_of_children          0
# No_of_weekendnights     0
# No_of weeknights        0
# Meal_type               0
# Car_parking             0
# Room_type               0
# Lead_time               0
# Market_seg_type         0
# repeated                0
# P-C                     0
# P-not-C                 0
# Average_price           0
# Special_request         0
# Date_of_reservation    37
# booking status          0
# Year                   37
# Month                  37
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
numerical_columns = df.select_dtypes(include="number")
print(len(numerical_columns.columns))
# Out:
# 13

# %%
# Values closer to +1 or -1 = stronger relationship

#### Mapping the column booking status with 0 and 1 to enbble pandas read it

df['booking status'] = df['booking status'].map({'Not_Canceled': 0, 'Canceled': 1})

corr_cols = numerical_cols + ['booking status']
correlation_matrix = df[corr_cols].corr()

plt.figure(figsize=(11, 8))
sns.heatmap(correlation_matrix, annot=True, fmt='.2f',
            cmap='RdBu_r', center=0, linewidths=0.5, square=True)
plt.title('Correlation Matrix', fontsize=14, fontweight='bold')
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 7
#       1 # Values closer to +1 or -1 = stronger relationship
#       2
#       3 #### Mapping the column booking status with 0 and 1 to enbble pandas read it
#       5 df['booking status'] = df['booking status'].map({'Not_Canceled': 0, 'Canceled': 1})
# ----> 7 corr_cols = numerical_cols + ['booking status']
#       8 correlation_matrix = df[corr_cols].corr()
#      10 plt.figure(figsize=(11, 8))
#
# NameError: name 'numerical_cols' is not defined

# %%
fig, ax = plt.subplots(nrows=4,ncols=4, figsize=(20,20))
ax = ax.flatten()
for nk, col in enumerate(numerical_columns):
    sns.histplot(df[col], ax=ax[nk])
plt.show()

# %%
fig, ax = plt.subplots(nrows=4,ncols=4, figsize=(20,20))
ax = ax.flatten()
for nk, col in enumerate(numerical_columns):
    sns.boxplot(df[col], ax=ax[nk])
plt.show()

# %%
cols = ("NO_of weeknights","Car_parking", "Average_price","P-not-C","No_of_weekendnights","Special_request","Lead_time","No_of_adult ")
for nk in cols:
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1

    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR

    df = df[(df[col] >= lower_bound) & (df[col] <= upper_bound)]

print("Outliers removed")
# Out:
# Outliers removed

# %%
fig, ax = plt.subplots(nrows=4,ncols=4, figsize=(20,20))
ax = ax.flatten()
for nk, col in enumerate(numerical_columns):
    sns.boxplot(df[col], ax=ax[nk])
plt.show()

# %%
df.duplicated(). sum()

# %%
Lead_time= df["Lead_time"].mean()
print(Lead_time)
# Out:
# 85.28236040609137

# %%
No_of_children= df["No_of_children"].mean()
print(No_of_children)
# Out:
# 0.10530236150960053

# %%
month= df["Month"].mean()
print(month)
# Out:
# 4.85008828073273

# %%
Adult_Nu= df["No_of_adult"].mean()
print(kid_number)
# Out:
# 1.8451776649746192

# %%
avg_weekend= df["No_of_weekendnights"].mean()
print(avg_weekend)
# Out:
# 0.8104447141911277

# %%
avg_price= df["Average_price"].mean()
print(avg_price)
# Out:
# 103.43535036415803

# %%
avg_weekend= df["No_of weeknights"].mean()
print(avg_weekend)
# Out:
# 2.20450783491503

# %%
avg_parking= df["Car_parking"].value_counts(normalize="true")*100
print(avg_parking)
# Out:
# Car_parking
# 0    96.907416
# 1     3.092584
# Name: proportion, dtype: float64

# %%
avg_booking= df["booking status"].mean()
print(avg_booking)
# Out:
# 0.5

# %%
df.head()
# Out:
#   Booking_ID  No_of_adult  No_of_children  No_of_weekendnights  \
# 0   INN00001            1               1                    2
# 1   INN00002            1               0                    1
# 2   INN00003            2               1                    1
# 3   INN00004            1               0                    0
# 4   INN00005            1               0                    1
#
#    No_of weeknights  Meal_type  Car_parking  Room_type  Lead_time  \
# 0                 5          0            0          0        224
# 1                 3          3            0          0          5
# 2                 3          0            0          0          1
# 3                 2          0            0          0        211
# 4                 2          3            0          0         48
#
#    Market_seg_type  repeated  P-C  P-not-C  Average_price  Special_request  \
# 0                3         0    0        0          88.00                0
# ...

# %%
df['repeated'].value_counts(normalize="ture")*100
# Out:
# repeated
# 0    97.445376
# 1     2.554624
# Name: proportion, dtype: float64

# %%
market_type = df.groupby("Market_seg_type")["Booking_ID"].count()

print(market_type)
# Out:
# Market_seg_type
# Aviation           125
# Complementary      391
# Corporate         2017
# Offline          10531
# Online           23221
# Name: Booking_ID, dtype: int64

# %%
target_counts = df['Room_type'].value_counts()
target_pct = df['Room_type'].value_counts(normalize=True) * 100

# Print results dynamically
for val in target_counts.index:
    print(f"{val}: {target_counts[val]:,} ({target_pct[val]:.1f}%)")

# Visualization


fig, axes = plt.subplots(1, 2, figsize=(12, 8))
axes[1].pie(target_counts.values,
            labels=target_counts.index.astype(str),
            autopct='%1.1f%%')
axes[1].set_title('Room_type (%)')

plt.tight_layout()
plt.show()
# Out:
# 0: 28,113 (77.6%)
# 3: 6,051 (16.7%)
# 5: 964 (2.7%)
# 1: 692 (1.9%)
# 4: 263 (0.7%)
# 6: 158 (0.4%)
# 2: 7 (0.0%)

# %%
target_counts = df['Meal_type'].value_counts()
target_pct = df['Meal_type'].value_counts(normalize=True) * 100

for val in target_counts.index:
    print(f"{val}: {target_counts[val]:,} ({target_pct[val]:.1f}%)")


fig, axes = plt.subplots(1, 2, figsize=(12, 5))
axes[1].pie(target_counts.values,
            labels=target_counts.index.astype(str),
            autopct='%1.1f%%')
axes[1].set_title('Meal type (%)')

plt.tight_layout()
plt.show()
# Out:
# 0: 27,809 (76.7%)
# 3: 5,131 (14.2%)
# 1: 3,303 (9.1%)
# 2: 5 (0.0%)

# %%
Room_type = df.groupby("Room_type")["Booking_ID"].count()

print(Room_type)
# Out:
# Room_type
# Room_Type 1    28138
# Room_Type 2      692
# Room_Type 3        7
# Room_Type 4     6059
# Room_Type 5      265
# Room_Type 6      966
# Room_Type 7      158
# Name: Booking_ID, dtype: int64

# %%
No_children	= df.groupby("No_of_children")["Booking_ID"].count()
print(No_children)
# Out:
# No_of_children
# 0     33583
# 1      1622
# 2      1058
# 3        19
# 9         2
# 10        1
# Name: Booking_ID, dtype: int64

# %%
Room_type = df.groupby("Room_type")["booking status"].count()

print(Room_type)
# Out:
# Room_type
# 0    28113
# 1      692
# 2        7
# 3     6051
# 4      263
# 5      964
# 6      158
# Name: booking status, dtype: int64

# %%
sns.countplot(
    x="Month",
    data=df,
    order=df["Month"].value_counts().index, color="purple")
# Out:
# <Axes: xlabel='Month', ylabel='count'>

# %%
df["booking status"]. value_counts(normalize="true")*100
sns.countplot(
    x='Meal_type',
    data=df,
    order=df['Meal_type'].value_counts().index,color='purple')
# Out:
# <Axes: xlabel='Meal_type', ylabel='count'>

# %%
sns.countplot(
    x="Year",
    data=df,
    order=df["Year"].value_counts().index, color="purple")
# Out:
# <Axes: xlabel='Year', ylabel='count'>

# %%
 sns.countplot(
    x="booking status",
    data=df,
    order=df["booking status"].value_counts().index, color="grey")
# Out:
# <Axes: xlabel='booking status', ylabel='count'>

# %%
df['booking status'].value_counts(normalize='true')*100
# Out:
# booking status
# Not_Canceled    67.22026
# Canceled        32.77974
# Name: proportion, dtype: float64

# %%
Room_type = df.groupby("Room_type")["Booking_ID"].count()*100
print(Room_type)
# Out:
# Room_type
# Room_Type 1    2813800
# Room_Type 2      69200
# Room_Type 3        700
# Room_Type 4     605900
# Room_Type 5      26500
# Room_Type 6      96600
# Room_Type 7      15800
# Name: Booking_ID, dtype: int64

# %%
Special_request = df.groupby("booking status")["Booking_ID"].count()
print(Special_request)
# Out:
# booking status
# Canceled        11889
# Not_Canceled    24396
# Name: Booking_ID, dtype: int64

# %%
adult_perf = df.groupby(["No_of_adult", "Market_seg_type"])["Booking_ID"].count().reset_index()

plt.figure(figsize=(15,5))
sns.barplot(x="No_of_adult",y="Booking_ID",data=adult_perf,hue="Market_seg_type")

plt.title("Booking Count by Adults and Market Segment")
plt.show()

# %%
Market_seg = df["Market_seg_type"].value_counts(normalize="true")*100
print(Market_seg)
# Out:
# Market_seg_type
# 4    64.006290
# 3    29.025050
# 2     5.547892
# 1     1.075921
# 0     0.344847
# Name: proportion, dtype: float64

# %%
df.head()
# Out:
#   Booking_ID  No_of_adult  No_of_children  No_of_weekendnights  \
# 0   INN00001            1               1                    2
# 1   INN00002            1               0                    1
# 2   INN00003            2               1                    1
# 3   INN00004            1               0                    0
# 4   INN00005            1               0                    1
#
#    No_of weeknights     Meal_type  Car_parking    Room_type  Lead_time  \
# 0                 5   Meal Plan 1            0  Room_Type 1        224
# 1                 3  Not Selected            0  Room_Type 1          5
# 2                 3   Meal Plan 1            0  Room_Type 1          1
# 3                 2   Meal Plan 1            0  Room_Type 1        211
# 4                 2  Not Selected            0  Room_Type 1         48
#
#   Market_seg_type  repeated  P-C  P-not-C  Average_price  Special_request  \
# 0         Offline         0    0        0          88.00                0
# ...

# %%
Special_request = df.groupby("Special_request")["Booking_ID"].count()
print(Special_request)
# Out:
# Special_request
# 0    19780
# 1    11379
# 2     4364
# 3      676
# 4       78
# 5        8
# Name: Booking_ID, dtype: int64

# %%
# Count each meal type
Meal_type = df.groupby("Meal_type")["Booking_ID"].count()

# Display values
print(Meal_type)

# Plot
sns.barplot(
    x=Meal_type.index,
    y=Meal_type.values,
    color="purple"
).set_title("Meal Type")
# Out:
# Meal_type
# Meal Plan 1     27842
# Meal Plan 2      3306
# Meal Plan 3         5
# Not Selected     5132
# Name: Booking_ID, dtype: int64
# Text(0.5, 1.0, 'Meal Type')

# %%
Meal_type = df["Meal_type"].value_counts()
print(Meal_type)
# Out:
# Meal_type
# Meal Plan 1     27842
# Not Selected     5132
# Meal Plan 2      3306
# Meal Plan 3         5
# Name: count, dtype: int64

# %%
sns.barplot(
    x="No_of_adult",
    y="Average_price",
    data=df,
    hue="Market_seg_type")
# Out:
# <Axes: xlabel='No_of_adult', ylabel='Average_price'>

# %%
df.head()
# Out:
#   Booking_ID  No_of_adult  No_of_children  No_of_weekendnights  \
# 0   INN00001            1               1                    2
# 1   INN00002            1               0                    1
# 2   INN00003            2               1                    1
# 3   INN00004            1               0                    0
# 4   INN00005            1               0                    1
#
#    No_of weeknights  Meal_type  Car_parking  Room_type  Lead_time  \
# 0                 5          0            0          0        224
# 1                 3          3            0          0          5
# 2                 3          0            0          0          1
# 3                 2          0            0          0        211
# 4                 2          3            0          0         48
#
#    Market_seg_type  repeated  P-C  P-not-C  Average_price  Special_request  \
# 0                3         0    0        0          88.00                0
# ...

# %%
sns.countplot(
    x="P-C",
    data=df,
    order=df["P-C"].value_counts().index,
    color="green")
# Out:
# <Axes: xlabel='P-C', ylabel='count'>

# %%
sns.countplot(
    x="Lead_time",
    data=df,
    order=df["Lead_time"].value_counts().index,
    color="yellow")
# Out:
# <Axes: xlabel='Lead_time', ylabel='count'>

# %%
sns.countplot(
    x="Car_parking",
    data=df,
    order=df["Car_parking"].value_counts().index,
    color="yellow")
# Out:
# <Axes: xlabel='Car_parking', ylabel='count'>

# %%
sns.countplot(
    x="Market_seg_type",
    data=df,
    order=df["Market_seg_type"].value_counts().index,
    color="green")
# Out:
# <Axes: xlabel='Market_seg_type', ylabel='count'>

# %%
fig, axe = plt.subplots(nrows=3,ncols=3,figsize=(30,20))
market_seg = df.groupby("Market_seg_type")["Booking_ID"].count().reset_index()
sns.barplot(x="Market_seg_type",y="Booking_ID",data=market_seg,ax=axe[0,0],color="green")
axe[0,0].set_title("market segment")


number_children = df.groupby("No_of_children")["Booking_ID"].count().reset_index()
sns.barplot(x="No_of_children",y="Booking_ID",data=number_children,ax=axe[0,1],color="green")
axe[0,1].set_title("number_children")

average_price = df.groupby("No_of_children")["Average_price"].count().reset_index()
sns.barplot(x="No_of_children",y="Average_price",data=average_price	,ax=axe[0,2],color="green")
axe[0,2].set_title("average_price")

room_perf = df.groupby("Room_type")["booking status"].count().reset_index()
sns.barplot(x="Room_type",y="booking status",data=room_perf	,ax=axe[1,0],color="purple")
axe[1,0].set_title("room perfermance")

P_C = df.groupby("P-C")["Special_request"].count().reset_index()
sns.barplot(x="P-C",y="Special_request",data=P_C,ax=axe[1,1],color="purple")
axe[1,1].set_title("P-C performance")
# Out:
# Text(0.5, 1.0, 'P-C performance')

# %%
df["Lead_time"]
# Out:
# 0        224
# 1          5
# 2          1
# 3        211
# 4         48
#         ...
# 36280    346
# 36281     34
# 36282     83
# 36283    121
# 36284     44
# Name: Lead_time, Length: 36248, dtype: int64

# %%
df.head(20)
# Out:
#    Booking_ID  No_of_adult  No_of_children  No_of_weekendnights  \
# 0    INN00001            1               1                    2
# 1    INN00002            1               0                    1
# 2    INN00003            2               1                    1
# 3    INN00004            1               0                    0
# 4    INN00005            1               0                    1
# 5    INN00006            1               0                    0
# 6    INN00007            1               1                    1
# 7    INN00008            3               0                    1
# 8    INN00009            1               1                    0
# 9    INN00010            2               0                    0
# 10   INN00011            1               0                    1
# 11   INN00012            1               0                    2
# 12   INN00013            2               0                    2
# 13   INN00014            1               0                    2
# ...

# %%
# !pip install scikit-learn

# %%
encoder = LabelEncoder()

# %%
encoder.fit(df["Market_seg_type"])
# Out:
# LabelEncoder()

# %%
df["Market_seg_type"] = encoder.fit_transform(df["Market_seg_type"])
df["Meal_type"] = encoder.fit_transform(df["Meal_type"])
df["Room_type"] = encoder.fit_transform(df["Room_type"])
df["booking status"] = encoder.fit_transform(df["booking status"])

# %%
encoder.fit(df["repeated"])
# Out:
# LabelEncoder()

# %%
encoder.transform(df["repeated"])
# Out:
# array([0, 0, 0, ..., 0, 0, 0], shape=(36248,))

# %%
encoder.fit(df["booking status"])
# Out:
# LabelEncoder()

# %%
 encoder. transform(df["booking status"])
# Out:
# array([1, 1, 0, ..., 1, 1, 1], shape=(36248,))

# %%
encoder.fit(df["Meal_type"])
# Out:
# LabelEncoder()

# %%
encoder.transform(df["Meal_type"])
# Out:
# array([0, 3, 0, ..., 0, 0, 0], shape=(36248,))

# %%
df.head(10)
# Out:
#    Booking_ID  No_of_adult  No_of_children  No_of_weekendnights  \
# 0    INN00001            1               1                    2
# 1    INN00002            1               0                    1
# 2    INN00003            2               1                    1
# 3    INN00004            1               0                    0
# 4    INN00005            1               0                    1
# 5    INN00006            1               0                    0
# 6    INN00007            1               1                    1
# 7    INN00008            3               0                    1
# 8    INN00009            1               1                    0
# 10   INN00011            1               0                    1
#
#     No_of weeknights  Meal_type  Car_parking  Room_type  Lead_time  \
# 0                  5          0            0          0        224
# 1                  3          3            0          0          5
# ...

# %% [markdown]
# ## scaling of data for

# %%
num_cols_scale = ["Lead_time","Average_price","No_of_weekendnights","No_of weeknights","P-not-C"]

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
df[num_cols_scale] = scaler.fit_transform(df[num_cols_scale])

# %%
df.head()
# Out:
#   Booking_ID  No_of_adult  No_of_children  No_of_weekendnights  \
# 0   INN00001            1               1             1.365851
# 1   INN00002            1               0             0.217648
# 2   INN00003            2               1             0.217648
# 3   INN00004            1               0            -0.930555
# 4   INN00005            1               0             0.217648
#
#    No_of weeknights  Meal_type  Car_parking  Room_type  Lead_time  \
# 0          1.981487          0            0          0   1.613740
# 1          0.563857          3            0          0  -0.933946
# 2          0.563857          0            0          0  -0.980479
# 3         -0.144958          0            0          0   1.462507
# 4         -0.144958          3            0          0  -0.433716
#
#    Market_seg_type  repeated  P-C   P-not-C  Average_price  Special_request  \
# 0                3         0    0 -0.087228      -0.439994                0
# ...

# %%
df["booking status"]. value_counts(normalize="true")*100
# Out:
# booking status
# 1    67.22026
# 0    32.77974
# Name: proportion, dtype: float64

# %%
df["booking status"]. value_counts(normalize="true")*100
# Out:
# booking status
# 1    67.22026
# 0    32.77974
# Name: proportion, dtype: float64

# %%
sns.countplot(x="booking status",
    data=df,
    order=df["booking status"].value_counts().index,
    color="purple")
# Out:
# <Axes: xlabel='booking status', ylabel='count'>

# %% [markdown]
# # handling inbalance

# %%
# !pip install imbalanced-learn

# %%
from imblearn.over_sampling import SMOTE

# %% [markdown]
# ## sperating our data

# %%
x = df.drop(columns=["booking status", "Booking_ID","Date_of_reservation"], axis=1)
y = df["booking status"]

# %%
x.head()
# Out:
#    No_of_adult  No_of_children  No_of_weekendnights  No_of weeknights  \
# 0            1               1             1.371120          1.988845
# 1            1               0             0.221058          0.568421
# 2            2               1             0.221058          0.568421
# 3            1               0            -0.929005         -0.141790
# 4            1               0             0.221058         -0.141790
#
#    Meal_type  Car_parking  Room_type  Lead_time  Market_seg_type  repeated  \
# 0          0            0          0   1.605096                3         0
# 1          3            0          0  -0.934144                4         0
# 2          0            0          0  -0.980523                4         0
# 3          0            0          0   1.454365                4         0
# 4          3            0          0  -0.435571                4         0
#
#    P-C   P-not-C  Average_price  Special_request
# ...

# %%
y.head()
# Out:
# 0    1
# 1    1
# 2    0
# 3    0
# 4    0
# Name: booking status, dtype: int64

# %%
smote = SMOTE(random_state=42)

# %%
x_resample, y_resample = smote.fit_resample(x, y)

# %%
y_resample.value_counts()
# Out:
# booking status
# 1    24366
# 0    24366
# Name: count, dtype: int64

# %%
y_resample.value_counts(normalize="true")*100
# Out:
# booking status
# 1    50.0
# 0    50.0
# Name: proportion, dtype: float64

# %%
df = pd.DataFrame(x_resample, columns=x.columns)

# %%
df["booking status"] = y_resample

# %%
y_resample.value_counts()
# Out:
# booking status
# 1    23634
# 0    23634
# Name: count, dtype: int64

# %%
y_resample.value_counts(normalize="true")*100
# Out:
# booking status
# 1    50.0
# 0    50.0
# Name: proportion, dtype: float64

# %%
#Training_test_split

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x_resample, y_resample, test_size=0.2, random_state=42)

# %%
print(f"training size {len(x_train)}")
print(f"testing size {len(x_test)}")
# Out:
# training size 38985
# testing size 9747

# %%
y_train.value_counts(normalize="true")*100
# Out:
# booking status
# 0    50.129537
# 1    49.870463
# Name: proportion, dtype: float64

# %%
y_test.value_counts(normalize="true")*100
# Out:
# booking status
# 1    50.518108
# 0    49.481892
# Name: proportion, dtype: float64

# %%
from sklearn.linear_model import LogisticRegression

# %%
model = LogisticRegression(random_state=42, class_weight="balanced")

# %%
#traing model
model.fit(x_train,y_train)
# Out:
# LogisticRegression(random_state=42)

# %%
y_pred = model.predict(x_test)

# %%
y_pred[:8]
# Out:
# array([1, 0, 1, 0, 1, 0, 1, 0])

# %%
print(y_test[:8])
# Out:
# 34074    0
# 5045     0
# 26566    1
# 18523    1
# 28320    1
# 2084     1
# 31265    1
# 8672     0
# Name: booking status, dtype: int64

# %%
from sklearn.metrics import classification_report, confusion_matrix

# %%
report = classification_report(y_test, y_pred)
matrix = confusion_matrix(y_test, y_pred)

# %% [raw]
# print("Logistic Regression Classification Report")

# %%
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.79      0.76      0.78      4785
#            1       0.76      0.79      0.78      4669
#
#     accuracy                           0.78      9454
#    macro avg       0.78      0.78      0.78      9454
# weighted avg       0.78      0.78      0.78      9454

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf_model = RandomForestClassifier(random_state=42)

# %%
#traing model
rf_model.fit(x_train,y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
y_pred = model.predict(x_test)

# %%
y_pred[:6]
# Out:
# array([1, 0, 1, 0, 1, 0])

# %%
print(y_test[:6])
# Out:
# 34074    0
# 5045     0
# 26566    1
# 18523    1
# 28320    1
# 2084     1
# Name: booking status, dtype: int64

# %%
from sklearn.metrics import classification_report, confusion_matrix

# %%
report = classification_report(y_test, y_pred)
matrix = confusion_matrix(y_test, y_pred)

# %%
print("Random Forest Classifier Report")
# Out:
# Random Forest Classifier Report

# %%
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.79      0.76      0.78      4785
#            1       0.76      0.79      0.78      4669
#
#     accuracy                           0.78      9454
#    macro avg       0.78      0.78      0.78      9454
# weighted avg       0.78      0.78      0.78      9454

# %% [markdown]
# ##trying multiply models

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier, AdaBoostClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier

# %%
models = {
    "Logistic Regression": LogisticRegression(random_state=42, class_weight="balanced"),
    "Random Forest": RandomForestClassifier(random_sate=42,class_weight="balanced")
    "Gradient Boosting": GradientBoostingClassifier(random_state=42),
    "AdaBoost": AdaBoostClassifier(random_state=42),
    "SVM": SVC(random_sate=42, class_weight="balanced"),
    "KNN": KNeighborsClassifier(),
    "Decision Tree": DecisionTreeClassifier(random_state=42)}

# %%
models.items()
# Out:
# dict_items([('Logistic Regression', LogisticRegression(class_weight='balanced', random_state=42)), ('Random Forest', RandomForestClassifier(class_weight='balanced', random_state=42)), ('Gradient Boosting', GradientBoostingClassifier(random_state=42)), ('Ada Boost', AdaBoostClassifier(random_state=42)), ('SVC', SVC(random_state=42)), ('KNeighbors classifier', KNeighborsClassifier()), ('Decision Tree', DecisionTreeClassifier(random_state=42))])

# %%
for model_name, model in models.items():
    print(f"training{model_name}....")
    #training the model
    model.fit(x_train,y_train)
    # predicting model
    y_pred = model.predict(x_test)
    #evaluating the model
    accuracy = accuracy_score(y_test,y_pred)
    report = classification_report(y_test, y_pred)
    matrix = confusion_matrix(y_test, y_pred)

    #stores result
    results[model_name] = {
    "accuracy": accuracy,
    "classification_report": report,
    "confusion_matrix": matrix
}
    print(f"{model_name} Classification Report")
    print(report)
    sns.heatmap(matrix, annot=True, fmt="g")
    plt.show()
# Out:
# trainingLogistic Regression....
# Logistic Regression Classification Report
#               precision    recall  f1-score   support
#
#            0       0.79      0.76      0.78      4785
#            1       0.77      0.79      0.78      4669
#
#     accuracy                           0.78      9454
#    macro avg       0.78      0.78      0.78      9454
# weighted avg       0.78      0.78      0.78      9454
# trainingRandom Forest....
# Random Forest Classification Report
#               precision    recall  f1-score   support
#
#            0       0.91      0.89      0.90      4785
#            1       0.89      0.91      0.90      4669
#
#     accuracy                           0.90      9454
#    macro avg       0.90      0.90      0.90      9454
# weighted avg       0.90      0.90      0.90      9454
# trainingGradient Boosting....
# Gradient Boosting Classification Report
#               precision    recall  f1-score   support
#
# ...

# %%
from sklearn.model_selection import GridSearchCV

# %%
RandomForestClassifier(random_state=42,class_weight="balanced")
# Out:
# RandomForestClassifier(class_weight='balanced', random_state=42)

# %%
from sklearn.model_selection import GridSearchCV

# %%
parameter_grid = {
    "n_estimators": [50,100, 200],
    "max_depth": [None,10,20,30],
    "min_samples_split": [2, 5 ,10],
    "min_samples_leaf": [1, 2,4]}

# %%
grid_search = GridSearchCV(RandomForestClassifier(random_state=42,class_weight="balanced"),
                           param_grid = parameter_grid,
                           scoring = "f1",
                           cv=5,
                           n_jobs=-1)

# %%
grid_search.fit(x_train, y_train)
# Out:
# GridSearchCV(cv=5,
#              estimator=RandomForestClassifier(class_weight='balanced',
#                                               random_state=42),
#              n_jobs=-1,
#              param_grid={'max_depth': [None, 10, 20, 30],
#                          'min_samples_leaf': [1, 2, 4],
#                          'min_samples_split': [2, 5, 10],
#                          'n_estimators': [50, 100, 200]},
#              scoring='f1')

# %%
print(f"Best Hyperparameters: {grid_search.best_params_}")
# Out:
# Best Hyperparameters: {'max_depth': 30, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 200}

# %%
best_rf = grid_search.best_estimator_

# %%
y_pred_best_rf = best_rf.predict(x_test)

# %%
print("fine tuned Random forest classifier")
report= classification_report(y_test, y_pred_best_rf)
print(report)
# Out:
# fine tuned Random forest classifier
#               precision    recall  f1-score   support
#
#            0       0.92      0.91      0.91      4823
#            1       0.91      0.92      0.92      4924
#
#     accuracy                           0.91      9747
#    macro avg       0.91      0.91      0.91      9747
# weighted avg       0.91      0.91      0.91      9747
